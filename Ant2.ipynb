# %%
# shared state object

class Nest:
  def __init__(self):
    self.input_features = [0.5, 0.5, 0.5] # tied to resources maybe? emergency situations? which impacts ant day to day?

    # do i want to convey resources in terms of need or amount? how does a worker ant change resource values + input features?
    self.resources = {
        'food': 100,
        'babies': 20 # TODO -- HOW ARE MORE BABIES MADE? SUCCESS OF NURSES? OR A CERTAIN NEST STATE FOOD WISE
    }
    self.danger = 3.0

    # TODO - NORMALIZE PHEROMONE VALUES: if one is out of 1 and other is out of 10...
    # role counts
    self.nurses = 0
    self.foragers = 0
    self.fighters = 0
    self.dead = 0

    self.n_scarcity = 0
    self.f_scarcity = 0

  def nursing_scarcity(self):
    if self.resources['babies'] == 0:
        return 0.0
    coverage_ratio = (3 * self.nurses) / self.resources['babies']
    scarcity = max(0.0, (1 - coverage_ratio) * 100)
    return scarcity

  def food_scarcity(self):
    population = self.nurses + self.foragers + self.fighters

    food_need = population * 2 # each ant eats 2

    #food_scarcity = max(0.0, (food_need - self.resources['food']) / food_need) # **TODO - cap between 0 and 1

    return min(1.0, max(0.0, (food_need - self.resources['food']) / food_need))

  def tick(self):

    # Decay
    self.input_features[1] = max(0.0, self.input_features[1] * 0.98)
    self.input_features[2] = max(0.0, self.input_features[2] * 0.97)

    # Baby pheromone
    baby_signal = 0.02 * self.resources['babies']
    nurse_reduction = 0.03 * self.nurses
    self.input_features[0] = max(0.0, self.input_features[0] + baby_signal - nurse_reduction)

    # Scarcity updates
    n_scarcity = self.nursing_scarcity() # TODO - how to update this per tick, how are new ants initialized? with scarcity not updated but pheromones updated?
    f_scarcity = self.food_scarcity()


  def summary(self):
    print("\n--- Pheromones ---")
    print(f"Baby     : {self.input_features[0]:.2f}")
    print(f"Food     : {self.input_features[1]:.2f}")
    print(f"Danger   : {self.input_features[2]:.2f}")

    print("\n--- Scarcity ---")
    print(f"Baby     : {self.n_scarcity:.2f}")
    print(f"Food     : {self.f_scarcity:.2f}")
    print(f"Danger   : {self.danger:.2f}")

    print("\n--- Resources ---")
    print(f"Food     : {self.resources['food']}")
    print(f"Babies   : {self.resources['babies']}")

  def concise_report(self, tick_report):
    print("\n--- Ant Status ---")
    print("Role      | Count | New | Action Summary")
    print("--------------------------------------------")

    print(f"Nurse     | {self.nurses:5} | {tick_report['nurse']['new']:3} | cared for babies")

    f = tick_report["forager"]
    print(f"Forager   | {self.foragers:5} | {f['new']:3} | {f['success']} success, {f['fail']} fail")

    f = tick_report["fighter"]
    print(f"Fighter   | {self.fighters:5} | {f['new']:3} | {f['win']} win, {f['retreat']} retreat, {f['death']} death")

    print(f"Dead      | {self.dead:5} | {tick_report['dead']['new']:3} | --")

# %%
import numpy as np
import random

class Ant:

  # input_features and weights have to be [] lists
  def __init__(self, nest: Nest):
    self.nest = nest
    self.summary = "Ant Summary: \n------------\n" # append latest messages to this:
    self.role = ""
    self.role = self.decide_role()
    self.location = 0 # dummy for now
    self.perception = [self.nest.input_features] # update with scarcity and other stuff

    # TODO: SET UP EXECUTION ONCE ROLE HAS BEEN RECEIVED
  # makes decision for ant
  def decide_role(self):

    input_features = self.nest.input_features

    options = [
      [.3, .3, .4],
      [.3, .4, .3],
      [.4, .3, .3]
    ]

    weights = random.choice(options)

    x = np.array(input_features)
    theta = np.array(weights)

    z = theta*x

    exp_z = np.exp(z - np.max(z))
    softmax = exp_z/exp_z.sum()

    decision_index = np.argmax(softmax)

    role = ["nurse", "forager", "fighter"][decision_index]
    # Update role

    self.update_role(role)

    return role

  def update_role(self, new_role, tick_report=None):

    if self.role:
      if self.role == "nurse": self.nest.nurses -= 1
      elif self.role == "forager": self.nest.foragers -= 1
      elif self.role == "fighter": self.nest.fighters -= 1

    if tick_report and new_role != self.role: # TODO - understand this
        tick_report[new_role]["new"] += 1

    self.role = new_role
    if self.role == "nurse": self.nest.nurses += 1
    elif self.role == "forager": self.nest.foragers += 1
    elif self.role == "fighter": self.nest.fighters += 1



  def act(self, tick_report):

    if self.role == "dead":
        return

    self.summary += f"\nAnt Role: {self.role}"

    if self.role == "nurse":
      # babies naturally increase
      self.nest.input_features[0] = max(0.0, self.nest.input_features[0] - .1) # reduce baby pheromones
    elif self.role == "forager":
      if random.random() < 0.7: # if success
        self.nest.resources['food'] += 5
        self.nest.input_features[1] += .1 # increase food pheromones
        tick_report["forager"]["success"] += 1
      else:
        tick_report["forager"]["fail"] += 1


    elif self.role == "fighter":
      r = random.random()
      if r < 0.5: # success
        self.nest.danger = max(0.0, self.nest.danger - .2)
        self.nest.input_features[2] = max(0.0, self.nest.input_features[2] - .1) # reduce danger pheromones
        tick_report["fighter"]["win"] += 1
      elif r < 0.9:  # retreat - TODO: is fight pheromone increased? location and spatial, when to totally give up
        self.nest.input_features[2] += .1 # TODO - why no max function for this?
        tick_report["fighter"]["retreat"] += 1
      else: # death
        self.update_role("dead", tick_report)
        self.nest.danger += .5
        self.nest.input_features[2] += .2
        tick_report["fighter"]["death"] += 1
        tick_report["dead"]["new"] += 1

    return self.summary.strip()

  # TODO: IMPLEMENT ROLE CHANGES
  def step(self):
    # update perception maybe
    # call decision()
    # choose new role
    # execute

    return

# %%
nest = Nest()
ants = [Ant(nest) for _ in range(20)]

for step in range(100):
  print(f"\n=== TICK {step} ===")
  # Initialize tick report
  tick_report = {
      "nurse": {"new": 0},
      "forager": {"new": 0, "success": 0, "fail": 0},
      "fighter": {"new": 0, "win": 0, "retreat": 0, "death": 0},
      "dead": {"new": 0}
  }
  for ant in ants:
    ant.act(tick_report)
  nest.tick()

  nest.concise_report(tick_report)
  nest.summary()


# improve pheromone updating(normalize somehow to keep 1 as total or something) + baby pheromone became negative. add babies or something, or set that cap
# fix scarcity not being calculated
# how to keep adding ants(babies growing, i spawn em in, etc...)
# when ant die in fight, danger level increases while danger pheromone decreases. decay?
# Out:
# === TICK 0 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 2 success, 7 fail
# Fighter   |     7 |   0 | 2 win, 5 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.38
# Food     : 0.69
# Danger   : 0.78
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 2.60
#
# --- Resources ---
# Food     : 110
# Babies   : 20
#
# === TICK 1 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 8 success, 1 fail
# Fighter   |     6 |   0 | 5 win, 1 retreat, 1 death
# Dead      |     0 |   2 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 1.46
# Danger   : 0.56
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 2.10
#
# --- Resources ---
# Food     : 150
# Babies   : 20
#
# === TICK 2 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     5 |   0 | 3 win, 2 retreat, 1 death
# Dead      |     0 |   2 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 2.02
# Danger   : 0.64
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 2.00
#
# --- Resources ---
# Food     : 180
# Babies   : 20
#
# === TICK 3 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 9 success, 0 fail
# Fighter   |     4 |   0 | 1 win, 3 retreat, 1 death
# Dead      |     0 |   2 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 2.86
# Danger   : 1.01
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 2.30
#
# --- Resources ---
# Food     : 225
# Babies   : 20
#
# === TICK 4 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     4 |   0 | 3 win, 1 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 3.39
# Danger   : 0.78
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 1.70
#
# --- Resources ---
# Food     : 255
# Babies   : 20
#
# === TICK 5 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 4 success, 5 fail
# Fighter   |     4 |   0 | 2 win, 2 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 3.71
# Danger   : 0.76
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 1.30
#
# --- Resources ---
# Food     : 275
# Babies   : 20
#
# === TICK 6 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     2 |   0 | 1 win, 1 retreat, 2 death
# Dead      |     0 |   4 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 4.23
# Danger   : 1.13
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 2.10
#
# --- Resources ---
# Food     : 305
# Babies   : 20
#
# === TICK 7 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     2 |   0 | 1 win, 1 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 4.73
# Danger   : 1.09
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 1.90
#
# --- Resources ---
# Food     : 335
# Babies   : 20
#
# === TICK 8 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 5 success, 4 fail
# Fighter   |     2 |   0 | 1 win, 1 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 5.12
# Danger   : 1.06
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 1.70
#
# --- Resources ---
# Food     : 360
# Babies   : 20
#
# === TICK 9 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     2 |   0 | 0 win, 2 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 5.61
# Danger   : 1.22
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 1.70
#
# --- Resources ---
# Food     : 390
# Babies   : 20
#
# === TICK 10 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     2 |   0 | 1 win, 1 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 6.09
# Danger   : 1.18
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 1.50
#
# --- Resources ---
# Food     : 420
# Babies   : 20
#
# === TICK 11 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 5 success, 4 fail
# Fighter   |     2 |   0 | 0 win, 2 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 6.45
# Danger   : 1.34
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 1.50
#
# --- Resources ---
# Food     : 445
# Babies   : 20
#
# === TICK 12 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 3 success, 6 fail
# Fighter   |     2 |   0 | 2 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 6.62
# Danger   : 1.11
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 1.10
#
# --- Resources ---
# Food     : 460
# Babies   : 20
#
# === TICK 13 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     2 |   0 | 2 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 7.07
# Danger   : 0.88
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.70
#
# --- Resources ---
# Food     : 490
# Babies   : 20
#
# === TICK 14 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 7 success, 2 fail
# Fighter   |     2 |   0 | 1 win, 1 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 7.62
# Danger   : 0.85
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 525
# Babies   : 20
#
# === TICK 15 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 4 success, 5 fail
# Fighter   |     2 |   0 | 0 win, 2 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 7.86
# Danger   : 1.02
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 545
# Babies   : 20
#
# === TICK 16 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     2 |   0 | 2 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 8.29
# Danger   : 0.80
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.10
#
# --- Resources ---
# Food     : 575
# Babies   : 20
#
# === TICK 17 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 8 success, 1 fail
# Fighter   |     1 |   0 | 0 win, 1 retreat, 1 death
# Dead      |     0 |   2 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 8.91
# Danger   : 1.07
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.60
#
# --- Resources ---
# Food     : 615
# Babies   : 20
#
# === TICK 18 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 9 success, 0 fail
# Fighter   |     1 |   0 | 1 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 9.61
# Danger   : 0.94
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.40
#
# --- Resources ---
# Food     : 660
# Babies   : 20
#
# === TICK 19 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 4 success, 5 fail
# Fighter   |     1 |   0 | 0 win, 1 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 9.81
# Danger   : 1.01
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.40
#
# --- Resources ---
# Food     : 680
# Babies   : 20
#
# === TICK 20 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 7 success, 2 fail
# Fighter   |     1 |   0 | 0 win, 1 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 10.30
# Danger   : 1.07
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.40
#
# --- Resources ---
# Food     : 715
# Babies   : 20
#
# === TICK 21 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 5 success, 4 fail
# Fighter   |     1 |   0 | 0 win, 1 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 10.59
# Danger   : 1.14
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.40
#
# --- Resources ---
# Food     : 740
# Babies   : 20
#
# === TICK 22 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 7 success, 2 fail
# Fighter   |     1 |   0 | 0 win, 1 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 11.06
# Danger   : 1.20
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.40
#
# --- Resources ---
# Food     : 775
# Babies   : 20
#
# === TICK 23 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 8 success, 1 fail
# Fighter   |     1 |   0 | 0 win, 1 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 11.62
# Danger   : 1.26
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.40
#
# --- Resources ---
# Food     : 815
# Babies   : 20
#
# === TICK 24 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 5 success, 4 fail
# Fighter   |     1 |   0 | 0 win, 1 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 11.88
# Danger   : 1.32
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.40
#
# --- Resources ---
# Food     : 840
# Babies   : 20
#
# === TICK 25 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 8 success, 1 fail
# Fighter   |     1 |   0 | 0 win, 1 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 12.43
# Danger   : 1.38
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.40
#
# --- Resources ---
# Food     : 880
# Babies   : 20
#
# === TICK 26 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     1 |   0 | 1 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 12.77
# Danger   : 1.24
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.20
#
# --- Resources ---
# Food     : 910
# Babies   : 20
#
# === TICK 27 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 8 success, 1 fail
# Fighter   |     1 |   0 | 0 win, 1 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 13.29
# Danger   : 1.30
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.20
#
# --- Resources ---
# Food     : 950
# Babies   : 20
#
# === TICK 28 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 7 success, 2 fail
# Fighter   |     1 |   0 | 0 win, 1 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 13.71
# Danger   : 1.36
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.20
#
# --- Resources ---
# Food     : 985
# Babies   : 20
#
# === TICK 29 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 5 success, 4 fail
# Fighter   |     1 |   0 | 1 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 13.93
# Danger   : 1.22
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.00
#
# --- Resources ---
# Food     : 1010
# Babies   : 20
#
# === TICK 30 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 4 success, 5 fail
# Fighter   |     1 |   0 | 1 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 14.04
# Danger   : 1.09
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.00
#
# --- Resources ---
# Food     : 1030
# Babies   : 20
#
# === TICK 31 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 3 success, 6 fail
# Fighter   |     1 |   0 | 1 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 14.06
# Danger   : 0.96
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.00
#
# --- Resources ---
# Food     : 1045
# Babies   : 20
#
# === TICK 32 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 7 success, 2 fail
# Fighter   |     1 |   0 | 1 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 14.46
# Danger   : 0.83
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.00
#
# --- Resources ---
# Food     : 1080
# Babies   : 20
#
# === TICK 33 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     1 |   0 | 1 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 14.76
# Danger   : 0.71
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.00
#
# --- Resources ---
# Food     : 1110
# Babies   : 20
#
# === TICK 34 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 4 success, 5 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 1 death
# Dead      |     0 |   2 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 14.86
# Danger   : 0.88
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1130
# Babies   : 20
#
# === TICK 35 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 15.15
# Danger   : 0.85
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1160
# Babies   : 20
#
# === TICK 36 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 5 success, 4 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 15.34
# Danger   : 0.83
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1185
# Babies   : 20
#
# === TICK 37 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 3 success, 6 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 15.32
# Danger   : 0.80
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1200
# Babies   : 20
#
# === TICK 38 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 15.60
# Danger   : 0.78
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1230
# Babies   : 20
#
# === TICK 39 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 7 success, 2 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 15.98
# Danger   : 0.76
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1265
# Babies   : 20
#
# === TICK 40 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 16.25
# Danger   : 0.73
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1295
# Babies   : 20
#
# === TICK 41 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 7 success, 2 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 16.61
# Danger   : 0.71
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1330
# Babies   : 20
#
# === TICK 42 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 8 success, 1 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 17.06
# Danger   : 0.69
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1370
# Babies   : 20
#
# === TICK 43 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 5 success, 4 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 17.21
# Danger   : 0.67
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1395
# Babies   : 20
#
# === TICK 44 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 8 success, 1 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 17.65
# Danger   : 0.65
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1435
# Babies   : 20
#
# === TICK 45 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 5 success, 4 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 17.78
# Danger   : 0.63
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1460
# Babies   : 20
#
# === TICK 46 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 8 success, 1 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 18.21
# Danger   : 0.61
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1500
# Babies   : 20
#
# === TICK 47 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 5 success, 4 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 18.34
# Danger   : 0.59
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1525
# Babies   : 20
#
# === TICK 48 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 7 success, 2 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 18.66
# Danger   : 0.58
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1560
# Babies   : 20
#
# === TICK 49 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 8 success, 1 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 19.07
# Danger   : 0.56
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1600
# Babies   : 20
#
# === TICK 50 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 5 success, 4 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 19.18
# Danger   : 0.54
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1625
# Babies   : 20
#
# === TICK 51 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 19.38
# Danger   : 0.53
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1655
# Babies   : 20
#
# === TICK 52 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 8 success, 1 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 19.78
# Danger   : 0.51
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1695
# Babies   : 20
#
# === TICK 53 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 8 success, 1 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 20.17
# Danger   : 0.49
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1735
# Babies   : 20
#
# === TICK 54 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 20.35
# Danger   : 0.48
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1765
# Babies   : 20
#
# === TICK 55 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 20.53
# Danger   : 0.46
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1795
# Babies   : 20
#
# === TICK 56 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 7 success, 2 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 20.81
# Danger   : 0.45
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1830
# Babies   : 20
#
# === TICK 57 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 8 success, 1 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 21.18
# Danger   : 0.44
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1870
# Babies   : 20
#
# === TICK 58 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 21.34
# Danger   : 0.42
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1900
# Babies   : 20
#
# === TICK 59 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 4 success, 5 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 21.31
# Danger   : 0.41
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1920
# Babies   : 20
#
# === TICK 60 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 7 success, 2 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 21.57
# Danger   : 0.40
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1955
# Babies   : 20
#
# === TICK 61 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 7 success, 2 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 21.82
# Danger   : 0.39
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 1990
# Babies   : 20
#
# === TICK 62 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 5 success, 4 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 21.87
# Danger   : 0.38
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2015
# Babies   : 20
#
# === TICK 63 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 5 success, 4 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 21.93
# Danger   : 0.36
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2040
# Babies   : 20
#
# === TICK 64 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 7 success, 2 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 22.17
# Danger   : 0.35
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2075
# Babies   : 20
#
# === TICK 65 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 22.32
# Danger   : 0.34
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2105
# Babies   : 20
#
# === TICK 66 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 8 success, 1 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 22.66
# Danger   : 0.33
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2145
# Babies   : 20
#
# === TICK 67 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 22.79
# Danger   : 0.32
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2175
# Babies   : 20
#
# === TICK 68 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 5 success, 4 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 22.82
# Danger   : 0.31
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2200
# Babies   : 20
#
# === TICK 69 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 5 success, 4 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 22.86
# Danger   : 0.30
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2225
# Babies   : 20
#
# === TICK 70 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 8 success, 1 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 23.19
# Danger   : 0.29
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2265
# Babies   : 20
#
# === TICK 71 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 4 success, 5 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 23.11
# Danger   : 0.29
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2285
# Babies   : 20
#
# === TICK 72 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 4 success, 5 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 23.04
# Danger   : 0.28
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2305
# Babies   : 20
#
# === TICK 73 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 8 success, 1 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 23.37
# Danger   : 0.27
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2345
# Babies   : 20
#
# === TICK 74 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 5 success, 4 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 23.39
# Danger   : 0.26
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2370
# Babies   : 20
#
# === TICK 75 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 7 success, 2 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 23.61
# Danger   : 0.25
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2405
# Babies   : 20
#
# === TICK 76 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 8 success, 1 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 23.92
# Danger   : 0.25
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2445
# Babies   : 20
#
# === TICK 77 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 7 success, 2 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 24.13
# Danger   : 0.24
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2480
# Babies   : 20
#
# === TICK 78 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 8 success, 1 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 24.43
# Danger   : 0.23
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2520
# Babies   : 20
#
# === TICK 79 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 24.53
# Danger   : 0.22
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2550
# Babies   : 20
#
# === TICK 80 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 24.63
# Danger   : 0.22
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2580
# Babies   : 20
#
# === TICK 81 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 4 success, 5 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 24.52
# Danger   : 0.21
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2600
# Babies   : 20
#
# === TICK 82 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 24.62
# Danger   : 0.20
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2630
# Babies   : 20
#
# === TICK 83 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 24.72
# Danger   : 0.20
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2660
# Babies   : 20
#
# === TICK 84 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 5 success, 4 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 24.71
# Danger   : 0.19
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2685
# Babies   : 20
#
# === TICK 85 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 24.81
# Danger   : 0.19
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2715
# Babies   : 20
#
# === TICK 86 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 8 success, 1 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 25.09
# Danger   : 0.18
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2755
# Babies   : 20
#
# === TICK 87 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 6 success, 3 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 25.18
# Danger   : 0.18
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2785
# Babies   : 20
#
# === TICK 88 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 5 success, 4 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 25.17
# Danger   : 0.17
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2810
# Babies   : 20
#
# === TICK 89 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 7 success, 2 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 25.35
# Danger   : 0.17
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2845
# Babies   : 20
#
# === TICK 90 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 8 success, 1 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 25.63
# Danger   : 0.16
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2885
# Babies   : 20
#
# === TICK 91 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 5 success, 4 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 25.60
# Danger   : 0.16
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2910
# Babies   : 20
#
# === TICK 92 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 5 success, 4 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 25.58
# Danger   : 0.15
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2935
# Babies   : 20
#
# === TICK 93 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 8 success, 1 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 25.85
# Danger   : 0.15
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 2975
# Babies   : 20
#
# === TICK 94 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 5 success, 4 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 25.83
# Danger   : 0.14
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 3000
# Babies   : 20
#
# === TICK 95 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 7 success, 2 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 26.00
# Danger   : 0.14
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 3035
# Babies   : 20
#
# === TICK 96 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 5 success, 4 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 25.97
# Danger   : 0.13
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 3060
# Babies   : 20
#
# === TICK 97 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 7 success, 2 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 26.13
# Danger   : 0.13
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 3095
# Babies   : 20
#
# === TICK 98 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 8 success, 1 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 26.40
# Danger   : 0.13
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 3135
# Babies   : 20
#
# === TICK 99 ===
#
# --- Ant Status ---
# Role      | Count | New | Action Summary
# --------------------------------------------
# Nurse     |     4 |   0 | cared for babies
# Forager   |     9 |   0 | 8 success, 1 fail
# Fighter   |     0 |   0 | 0 win, 0 retreat, 0 death
# Dead      |     0 |   0 | --
#
# --- Pheromones ---
# Baby     : 0.28
# Food     : 26.65
# Danger   : 0.12
#
# --- Scarcity ---
# Baby     : 0.00
# Food     : 0.00
# Danger   : 0.50
#
# --- Resources ---
# Food     : 3175
# Babies   : 20
